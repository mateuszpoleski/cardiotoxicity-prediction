# %% [markdown]
# Plik z modelami do klasyfikacji. Tym razem modele testowałem już tylko na połączeniu wszystkich trzech plików z fingerprintami, ze względnu na to, że w przypadku regresji zawsze w ten sposób orzymywałem najlepsze wyniki. Testowałem również jak model radzi sobie w zależności od ustalonego progu IC50 (progu od którego klasyfikujemy związek jako toksyczny). Podobnie jak dla regresji, większa ilość zmiennych poprawia wyniki modelu, jednak korzystanie tylko z małej części zmiennych jest w stanie osiągać dość podobne wyniki, a przy tym czas wykonania jest zdecydowanie mniejszy. W notebooku przetestowałem sporo modeli płytkich oraz prostą sieć neuronową. Do oceny wyników używałem accuracy oraz f1_score dla mniej zbalansowanych progów IC50. Najlepsze wynik podobnie jak w przypadku regresji otrzymaweł w modelach opartych ns SVM, dla progu IC50=10 000(tyle samo związków toksycznych i nietoksycznych) dochododziłem do accuracy ~80%. W przypadku sieci neuronowej było to nieco mniej. Dokładniejsze wyniki można prześledzić poniżej. Ze względu na to, że testowałem dośc dużo kombinacji modeli/danych/parametrów cały notebook liczy się dość długo. W razie własnych testów polecam wywoływać funkcje z ograniczoną liczbą zmiennych, wtedy powinno działać szybciej. Powinno dać się to zrobić przez usunięcie częsci parametrów w miejscu gdzie wywołuje główne funckje.

# %%
import numpy as np

from xgboost import XGBClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

from sklearn.model_selection import train_test_split, KFold, GridSearchCV
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

from warnings import filterwarnings

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

from tensorflow.keras.callbacks import History
from keras.callbacks import LearningRateScheduler
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
from keras.layers import Dropout
from keras.layers import BatchNormalization

import matplotlib.pyplot as plt

import utils

# %%
seed = 1

# %%
def SVC_RBF(X, y, cv):
    classifier = SVC(kernel='rbf')
    
    param_grid = {
        'C': [10, 100],
        'gamma':[0.001, 0.01, 0.1, 'auto'],
    }
    
    grid = GridSearchCV(classifier, param_grid, cv=cv, return_train_score=True)
    grid.fit(X, y)
    return grid

# %%
def SVC_Poly(X, y, cv):
    classifier = SVC(kernel='poly')
    
    param_grid = {
        'C': [0.01, 1],
        'coef0': [0.01, 1],
        'degree': [2]
    }
    
    grid = GridSearchCV(classifier, param_grid, cv=cv, return_train_score=True)
    grid.fit(X, y)
    return grid

# %%
def SVC_Linear(X, y, cv):
    classifier = LinearSVC(loss='squared_hinge', penalty='l2', dual=False, max_iter=50000)
    
    param_grid = {
        'C': [0.1, 1, 10],
    }
    
    grid = GridSearchCV(classifier, param_grid, cv=cv, return_train_score=True)
    grid.fit(X, y)
    return grid

# %%
def Logistic(X, y, cv):
    classifier = LogisticRegression(solver='liblinear')
    
    param_grid = {
        'C': [0.01, 0.1, 1, 10, 100, 1000],
    }
    
    grid = GridSearchCV(classifier, param_grid, cv=cv, return_train_score=True)
    grid.fit(X, y)
    return grid

# %%
def RandomForest(X, y, cv):
    classifier = RandomForestClassifier(random_state=seed, max_leaf_nodes=500)
    
    param_grid = {
        'n_estimators': [100, 500],
        'max_leaf_nodes': [2, 4, 8, 16]
    }
    
    grid = GridSearchCV(classifier, param_grid, cv=cv, return_train_score=True)
    grid.fit(X, y)
    return grid

# %%
def GradientBoosting(X, y, cv):
    classifier = GradientBoostingClassifier(random_state=seed)
    
    param_grid = {
        'n_estimators': [100, 500],
        'learning_rate': [0.01, 0.1]
    }
    
    grid = GridSearchCV(classifier, param_grid, cv=cv, return_train_score=True)
    grid.fit(X, y)
    return grid

# %%
def XGBoost(X, y, cv):
    classifier = XGBClassifier(use_label_encoder=False, verbosity=0)
    
    param_grid = {
        'max_depth': [3, 5, 8, 10],
        'learning_rate': [0.001, 0.01],
        'n_estimators': [50, 100],
    }
    
    grid = GridSearchCV(classifier, param_grid, cv=cv, return_train_score=True)
    grid.fit(X, y)
    return grid

# %%
def KNearestNeighbors(X, y, cv):
    classifier = KNeighborsClassifier(algorithm='ball_tree')
    
    param_grid = {
        'n_neighbors': [5, 10],
        'leaf_size': [20, 50],
    }
    
    grid = GridSearchCV(classifier, param_grid, cv=cv, return_train_score=True)
    grid.fit(X, y)
    return grid

# %%
def perform_classification(X, y):
    
    model_functions = [
    ("SVC RBF", SVC_RBF),
    ("SVC Poly", SVC_Poly),
    ("SVC Linear", SVC_Linear),
    ("Logistic", Logistic),
    ("Random Forest", RandomForest),
    ("Gradient Boosting", GradientBoosting),
    ("XGBoosting", XGBoost),
    ("K Nearest Neighbors", KNearestNeighbors),
    ]
    
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=seed)

    kfold = KFold(n_splits=5, random_state=seed, shuffle=True)
    
    np.seterr(divide='ignore', invalid='ignore')
    filterwarnings('ignore')

    print(f"{'Classification model:'.ljust(22)}   {'accuracy:'.ljust(8)}   F1:")

    best_accuracy = 0
    best_acc_result = ("None", 0, {})
    
    best_f1 = 0
    best_precision = 0
    best_recall = 0
    best_f1_result = ("None", 0, {})

    for (name, function) in model_functions:
        model = function(X_train, y_train, kfold)
        prediction = model.best_estimator_.predict(X_test)
        accuracy = accuracy_score(y_test, prediction)
        precision = precision_score(y_test, prediction)
        recall = recall_score(y_test, prediction)
        f1 = f1_score(y_test, prediction)
        if (accuracy > best_accuracy):
            best_accuracy = accuracy
            best_acc_result = (name, accuracy, model.best_params_)
        if (f1 > best_f1):
            best_f1 = f1
            best_precision = precision
            best_recall = recall
            best_f1_result = (name, f1, model.best_params_)

        print(f"{name.ljust(22)}   {str(round(accuracy, 6)).ljust(9)}   {str(round(f1, 6)).ljust(9)}   {model.best_params_}")

    print(f"\nBest accuracy\n{best_acc_result[0].ljust(22)}   {str(round(best_acc_result[1], 6)).ljust(9)}   {best_acc_result[2]}\n")
    print(f"\nBest F1\n{best_f1_result[0].ljust(22)}   {str(round(best_f1_result[1], 6)).ljust(9)}   {best_f1_result[2]}")
    print(f"{'    preccision'.ljust(22)}   {best_precision}")
    print(f"{'    recall'.ljust(22)}   {best_recall}")

# %%
for perc in [0.9, 0.8, 0.5, 0.3, 0.1, 0.01]:
#     df_hashed = utils.get_hashed_fingerprints(min_perc_used=perc)
#     df_maccsfp = utils.get_MACCSFP_fingerprints(min_perc_used=perc)
#     df_klekota = utils.get_KlekotaRoth_fingerprints(min_perc_used=perc)
    df_mixed = utils.get_mixed_fingerprints(min_perc_used=perc)
    dfs = [
#         (df_hashed, "Hashed Extended Fingerprints"), 
#         (df_maccsfp, "MACCSFP Fingerprints"), 
#         (df_klekota, "Klekota&Roth Fingerprints"), 
        (df_mixed, "Mixed Fingerprints")
    ]

    print(f'\nUsing fetures that are present in at least {perc*100}% of substances.\n')
    for df, title in dfs:
        for IC50_threshold in [500, 5_000, 10_000, 50_000]:
            print(f'IC50 threshold for classification: {IC50_threshold} \n\n')
            df_class = utils.classify_on_IC50(df.copy(), IC50_threshold)
            X = df_class.drop('IC50', axis=1)
            y = df_class['IC50']
            print(f'{round(y[y==1].shape[0]/y.shape[0] * 100, 2)}% of substances classified as toxic, {round(y[y==0].shape[0]/y.shape[0] * 100, 2)}% classified as non toxic.' , '\n')
            print(title, '\n')
            perform_classification(X, y)
            print()
    print('\n\n')
# Out:
# Preparing files for mixed fingerprints.
#
# Preparing (ready_sets/cardiotoxicity_hERG_MACCSFP.csv) file.
# DataFrame base shape: (11504, 167)
# Shape after removing wrong values: (10635, 167)
# Shape after removing least used features: (10635, 15)
# Shape after removing outliers: (10396, 15)
#
# Preparing (ready_sets/cardiotoxicity_hERG_KlekFP.csv) file.
# DataFrame base shape: (11504, 4861)
# Shape after removing wrong values: (10635, 4861)
# Shape after removing least used features: (10635, 9)
# Shape after removing outliers: (10396, 9)
#
# Preparing (ready_sets/cardiotoxicity_hERG_ExtFP.csv) file.
# DataFrame base shape: (11504, 1025)
# Shape after removing wrong values: (10635, 1025)
# Shape after removing least used features: (10635, 51)
# Shape after removing outliers: (10396, 51)
#
#
# Using fetures that are present in at least 90.0% of substances.
#
# IC50 threshold for classification: 500
#
#
# 11.55% of substances classified as toxic, 88.45% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.891827    0.294671    {'C': 100, 'gamma': 0.1}
# SVC Poly                 0.888462    0.205479    {'C': 1, 'coef0': 0.01, 'degree': 2}
# SVC Linear               0.882692    0.024       {'C': 0.1}
# Logistic                 0.879327    0.038314    {'C': 1}
# Random Forest            0.885096    0.0         {'max_leaf_nodes': 2, 'n_estimators': 100}
# Gradient Boosting        0.890865    0.250825    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.889904    0.202091    {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 100}
# K Nearest Neighbors      0.891827    0.271845    {'leaf_size': 50, 'n_neighbors': 10}
#
# Best accuracy
# SVC RBF                  0.891827    {'C': 100, 'gamma': 0.1}
#
#
# Best F1
# SVC RBF                  0.294671    {'C': 100, 'gamma': 0.1}
#     preccision           0.5875
#     recall               0.19665271966527198
#
# IC50 threshold for classification: 5000
#
#
# 37.78% of substances classified as toxic, 62.22% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.682212    0.453267    {'C': 10, 'gamma': 0.1}
# SVC Poly                 0.673558    0.437448    {'C': 1, 'coef0': 0.01, 'degree': 2}
# SVC Linear               0.6625      0.402044    {'C': 10}
# Logistic                 0.6625      0.394828    {'C': 0.1}
# Random Forest            0.666827    0.395815    {'max_leaf_nodes': 16, 'n_estimators': 500}
# Gradient Boosting        0.684615    0.444068    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.672115    0.414089    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.667308    0.438312    {'leaf_size': 20, 'n_neighbors': 10}
#
# Best accuracy
# Gradient Boosting        0.684615    {'learning_rate': 0.1, 'n_estimators': 500}
#
#
# Best F1
# SVC RBF                  0.453267    {'C': 10, 'gamma': 0.1}
#     preccision           0.631336405529954
#     recall               0.3535483870967742
#
# IC50 threshold for classification: 10000
#
#
# 50.17% of substances classified as toxic, 49.83% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.644712    0.71031     {'C': 100, 'gamma': 0.1}
# SVC Poly                 0.629808    0.694202    {'C': 1, 'coef0': 1, 'degree': 2}
# SVC Linear               0.598077    0.670607    {'C': 0.1}
# Logistic                 0.596635    0.664802    {'C': 0.01}
# Random Forest            0.607212    0.673852    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.615865    0.685557    {'learning_rate': 0.1, 'n_estimators': 100}
# XGBoosting               0.587019    0.478446    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.592308    0.505251    {'leaf_size': 50, 'n_neighbors': 10}
#
# Best accuracy
# SVC RBF                  0.644712    {'C': 100, 'gamma': 0.1}
#
#
# Best F1
# SVC RBF                  0.71031     {'C': 100, 'gamma': 0.1}
#     preccision           0.6138211382113821
#     recall               0.8427906976744186
#
# IC50 threshold for classification: 50000
#
#
# 91.26% of substances classified as toxic, 8.74% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.922115    0.958758    {'C': 10, 'gamma': 0.1}
# SVC Poly                 0.919231    0.957143    {'C': 1, 'coef0': 0.01, 'degree': 2}
# SVC Linear               0.916827    0.95639     {'C': 1}
# Logistic                 0.915385    0.955823    {'C': 0.01}
# Random Forest            0.91875     0.957463    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.922596    0.959044    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.920192    0.957868    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.917308    0.956212    {'leaf_size': 20, 'n_neighbors': 5}
#
# Best accuracy
# Gradient Boosting        0.922596    {'learning_rate': 0.1, 'n_estimators': 500}
#
#
# Best F1
# Gradient Boosting        0.959044    {'learning_rate': 0.1, 'n_estimators': 500}
#     preccision           0.9299457326097681
#     recall               0.9900210084033614
#
#
#
#
# Preparing files for mixed fingerprints.
#
# Preparing (ready_sets/cardiotoxicity_hERG_MACCSFP.csv) file.
# DataFrame base shape: (11504, 167)
# Shape after removing wrong values: (10635, 167)
# Shape after removing least used features: (10635, 25)
# Shape after removing outliers: (10396, 25)
#
# Preparing (ready_sets/cardiotoxicity_hERG_KlekFP.csv) file.
# DataFrame base shape: (11504, 4861)
# Shape after removing wrong values: (10635, 4861)
# Shape after removing least used features: (10635, 15)
# Shape after removing outliers: (10396, 15)
#
# Preparing (ready_sets/cardiotoxicity_hERG_ExtFP.csv) file.
# DataFrame base shape: (11504, 1025)
# Shape after removing wrong values: (10635, 1025)
# Shape after removing least used features: (10635, 84)
# Shape after removing outliers: (10396, 84)
#
#
# Using fetures that are present in at least 80.0% of substances.
#
# IC50 threshold for classification: 500
#
#
# 11.55% of substances classified as toxic, 88.45% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.911058    0.509284    {'C': 10, 'gamma': 0.1}
# SVC Poly                 0.89375     0.311526    {'C': 1, 'coef0': 0.01, 'degree': 2}
# SVC Linear               0.885577    0.084615    {'C': 10}
# Logistic                 0.887019    0.145455    {'C': 1}
# Random Forest            0.885096    0.0         {'max_leaf_nodes': 2, 'n_estimators': 100}
# Gradient Boosting        0.900962    0.379518    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.899038    0.313725    {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 100}
# K Nearest Neighbors      0.899038    0.355828    {'leaf_size': 20, 'n_neighbors': 10}
#
# Best accuracy
# SVC RBF                  0.911058    {'C': 10, 'gamma': 0.1}
#
#
# Best F1
# SVC RBF                  0.509284    {'C': 10, 'gamma': 0.1}
#     preccision           0.6956521739130435
#     recall               0.401673640167364
#
# IC50 threshold for classification: 5000
#
#
# 37.78% of substances classified as toxic, 62.22% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.759135    0.639827    {'C': 10, 'gamma': 0.1}
# SVC Poly                 0.722115    0.547731    {'C': 1, 'coef0': 0.01, 'degree': 2}
# SVC Linear               0.674038    0.456731    {'C': 1}
# Logistic                 0.675962    0.458199    {'C': 0.1}
# Random Forest            0.678365    0.381129    {'max_leaf_nodes': 16, 'n_estimators': 500}
# Gradient Boosting        0.732692    0.574924    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.704327    0.499593    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.721635    0.581949    {'leaf_size': 20, 'n_neighbors': 10}
#
# Best accuracy
# SVC RBF                  0.759135    {'C': 10, 'gamma': 0.1}
#
#
# Best F1
# SVC RBF                  0.639827    {'C': 10, 'gamma': 0.1}
#     preccision           0.7224025974025974
#     recall               0.5741935483870968
#
# IC50 threshold for classification: 10000
#
#
# 50.17% of substances classified as toxic, 49.83% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.709615    0.70334     {'C': 10, 'gamma': 0.1}
# SVC Poly                 0.680288    0.680135    {'C': 1, 'coef0': 0.01, 'degree': 2}
# SVC Linear               0.630288    0.637435    {'C': 1}
# Logistic                 0.624038    0.626908    {'C': 0.1}
# Random Forest            0.612981    0.637877    {'max_leaf_nodes': 16, 'n_estimators': 500}
# Gradient Boosting        0.676442    0.676908    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.658654    0.697615    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.686058    0.709131    {'leaf_size': 20, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.709615    {'C': 10, 'gamma': 0.1}
#
#
# Best F1
# K Nearest Neighbors      0.709131    {'leaf_size': 20, 'n_neighbors': 5}
#     preccision           0.6803418803418804
#     recall               0.7404651162790697
#
# IC50 threshold for classification: 50000
#
#
# 91.26% of substances classified as toxic, 8.74% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.927404    0.961072    {'C': 10, 'gamma': 0.1}
# SVC Poly                 0.926442    0.96092     {'C': 1, 'coef0': 0.01, 'degree': 2}
# SVC Linear               0.919231    0.957683    {'C': 0.1}
# Logistic                 0.915385    0.955823    {'C': 0.01}
# Random Forest            0.91875     0.957463    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.927404    0.96145     {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.921154    0.958185    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 50}
# K Nearest Neighbors      0.927404    0.961411    {'leaf_size': 20, 'n_neighbors': 10}
#
# Best accuracy
# SVC RBF                  0.927404    {'C': 10, 'gamma': 0.1}
#
#
# Best F1
# Gradient Boosting        0.96145     {'learning_rate': 0.1, 'n_estimators': 500}
#     preccision           0.9354197714853453
#     recall               0.9889705882352942
#
#
#
#
# Preparing files for mixed fingerprints.
#
# Preparing (ready_sets/cardiotoxicity_hERG_MACCSFP.csv) file.
# DataFrame base shape: (11504, 167)
# Shape after removing wrong values: (10635, 167)
# Shape after removing least used features: (10635, 59)
# Shape after removing outliers: (10396, 59)
#
# Preparing (ready_sets/cardiotoxicity_hERG_KlekFP.csv) file.
# DataFrame base shape: (11504, 4861)
# Shape after removing wrong values: (10635, 4861)
# Shape after removing least used features: (10635, 36)
# Shape after removing outliers: (10396, 36)
#
# Preparing (ready_sets/cardiotoxicity_hERG_ExtFP.csv) file.
# DataFrame base shape: (11504, 1025)
# Shape after removing wrong values: (10635, 1025)
# Shape after removing least used features: (10635, 264)
# Shape after removing outliers: (10396, 264)
#
#
# Using fetures that are present in at least 50.0% of substances.
#
# IC50 threshold for classification: 500
#
#
# 11.55% of substances classified as toxic, 88.45% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.930769    0.668203    {'C': 10, 'gamma': 0.01}
# SVC Poly                 0.922115    0.573684    {'C': 1, 'coef0': 0.01, 'degree': 2}
# SVC Linear               0.906731    0.426036    {'C': 0.1}
# Logistic                 0.910096    0.503979    {'C': 1}
# Random Forest            0.888942    0.079681    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.927885    0.619289    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.927885    0.609375    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.915865    0.588235    {'leaf_size': 20, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.930769    {'C': 10, 'gamma': 0.01}
#
#
# Best F1
# SVC RBF                  0.668203    {'C': 10, 'gamma': 0.01}
#     preccision           0.7435897435897436
#     recall               0.606694560669456
#
# IC50 threshold for classification: 5000
#
#
# 37.78% of substances classified as toxic, 62.22% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.811538    0.744792    {'C': 10, 'gamma': 0.01}
# SVC Poly                 0.808173    0.726899    {'C': 1, 'coef0': 0.01, 'degree': 2}
# SVC Linear               0.737019    0.624571    {'C': 0.1}
# Logistic                 0.736058    0.616352    {'C': 0.1}
# Random Forest            0.691827    0.370952    {'max_leaf_nodes': 16, 'n_estimators': 500}
# Gradient Boosting        0.802404    0.720218    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.797115    0.707756    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.776923    0.697128    {'leaf_size': 50, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.811538    {'C': 10, 'gamma': 0.01}
#
#
# Best F1
# SVC RBF                  0.744792    {'C': 10, 'gamma': 0.01}
#     preccision           0.7516425755584757
#     recall               0.7380645161290322
#
# IC50 threshold for classification: 10000
#
#
# 50.17% of substances classified as toxic, 49.83% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.782212    0.782942    {'C': 10, 'gamma': 0.01}
# SVC Poly                 0.765865    0.764848    {'C': 1, 'coef0': 0.01, 'degree': 2}
# SVC Linear               0.680288    0.686469    {'C': 1}
# Logistic                 0.683173    0.689298    {'C': 1}
# Random Forest            0.660096    0.645258    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.767788    0.770546    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.759615    0.757986    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.748558    0.750834    {'leaf_size': 50, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.782212    {'C': 10, 'gamma': 0.01}
#
#
# Best F1
# SVC RBF                  0.782942    {'C': 10, 'gamma': 0.01}
#     preccision           0.8073122529644269
#     recall               0.76
#
# IC50 threshold for classification: 50000
#
#
# 91.26% of substances classified as toxic, 8.74% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.9375      0.966321    {'C': 10, 'gamma': 0.01}
# SVC Poly                 0.934135    0.964971    {'C': 1, 'coef0': 1, 'degree': 2}
# SVC Linear               0.921154    0.958312    {'C': 0.1}
# Logistic                 0.923558    0.959634    {'C': 0.1}
# Random Forest            0.920192    0.958144    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.9375      0.966615    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.928365    0.962019    {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 100}
# K Nearest Neighbors      0.930769    0.963001    {'leaf_size': 20, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.9375      {'C': 10, 'gamma': 0.01}
#
#
# Best F1
# Gradient Boosting        0.966615    {'learning_rate': 0.1, 'n_estimators': 500}
#     preccision           0.9457286432160804
#     recall               0.9884453781512605
#
#
#
#
# Preparing files for mixed fingerprints.
#
# Preparing (ready_sets/cardiotoxicity_hERG_MACCSFP.csv) file.
# DataFrame base shape: (11504, 167)
# Shape after removing wrong values: (10635, 167)
# Shape after removing least used features: (10635, 80)
# Shape after removing outliers: (10396, 80)
#
# Preparing (ready_sets/cardiotoxicity_hERG_KlekFP.csv) file.
# DataFrame base shape: (11504, 4861)
# Shape after removing wrong values: (10635, 4861)
# Shape after removing least used features: (10635, 70)
# Shape after removing outliers: (10396, 70)
#
# Preparing (ready_sets/cardiotoxicity_hERG_ExtFP.csv) file.
# DataFrame base shape: (11504, 1025)
# Shape after removing wrong values: (10635, 1025)
# Shape after removing least used features: (10635, 655)
# Shape after removing outliers: (10396, 655)
#
#
# Using fetures that are present in at least 30.0% of substances.
#
# IC50 threshold for classification: 500
#
#
# 11.55% of substances classified as toxic, 88.45% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.927885    0.669604    {'C': 100, 'gamma': 0.01}
# SVC Poly                 0.923558    0.601504    {'C': 1, 'coef0': 0.01, 'degree': 2}
# SVC Linear               0.915865    0.588235    {'C': 0.1}
# Logistic                 0.916827    0.568579    {'C': 0.1}
# Random Forest            0.888942    0.079681    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.933173    0.660147    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.922115    0.597015    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.919712    0.61959     {'leaf_size': 50, 'n_neighbors': 5}
#
# Best accuracy
# Gradient Boosting        0.933173    {'learning_rate': 0.1, 'n_estimators': 500}
#
#
# Best F1
# SVC RBF                  0.669604    {'C': 100, 'gamma': 0.01}
#     preccision           0.7069767441860465
#     recall               0.6359832635983264
#
# IC50 threshold for classification: 5000
#
#
# 37.78% of substances classified as toxic, 62.22% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.820192    0.755875    {'C': 10, 'gamma': 0.01}
# SVC Poly                 0.820673    0.752159    {'C': 1, 'coef0': 1, 'degree': 2}
# SVC Linear               0.782212    0.703728    {'C': 0.1}
# Logistic                 0.783173    0.699133    {'C': 0.1}
# Random Forest            0.696154    0.370518    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.815385    0.742972    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.796154    0.71467     {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.787981    0.713822    {'leaf_size': 50, 'n_neighbors': 5}
#
# Best accuracy
# SVC Poly                 0.820673    {'C': 1, 'coef0': 1, 'degree': 2}
#
#
# Best F1
# SVC RBF                  0.755875    {'C': 10, 'gamma': 0.01}
#     preccision           0.7648612945838837
#     recall               0.7470967741935484
#
# IC50 threshold for classification: 10000
#
#
# 50.17% of substances classified as toxic, 49.83% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.790385    0.789168    {'C': 10, 'gamma': 0.01}
# SVC Poly                 0.784135    0.78527     {'C': 1, 'coef0': 0.01, 'degree': 2}
# SVC Linear               0.725481    0.731799    {'C': 10}
# Logistic                 0.733173    0.737091    {'C': 0.1}
# Random Forest            0.681731    0.663618    {'max_leaf_nodes': 16, 'n_estimators': 500}
# Gradient Boosting        0.780769    0.780769    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.774038    0.774038    {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 100}
# K Nearest Neighbors      0.755769    0.760377    {'leaf_size': 50, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.790385    {'C': 10, 'gamma': 0.01}
#
#
# Best F1
# SVC RBF                  0.789168    {'C': 10, 'gamma': 0.01}
#     preccision           0.8217522658610272
#     recall               0.7590697674418605
#
# IC50 threshold for classification: 50000
#
#
# 91.26% of substances classified as toxic, 8.74% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.937981    0.966915    {'C': 10, 'gamma': 'auto'}
# SVC Poly                 0.937019    0.966384    {'C': 1, 'coef0': 1, 'degree': 2}
# SVC Linear               0.924519    0.959253    {'C': 0.1}
# Logistic                 0.933654    0.964561    {'C': 0.1}
# Random Forest            0.921154    0.958628    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.936538    0.965997    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.928846    0.962051    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.93125     0.963249    {'leaf_size': 50, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.937981    {'C': 10, 'gamma': 'auto'}
#
#
# Best F1
# SVC RBF                  0.966915    {'C': 10, 'gamma': 'auto'}
#     preccision           0.9448621553884712
#     recall               0.9900210084033614
#
#
#
#
# Preparing files for mixed fingerprints.
#
# Preparing (ready_sets/cardiotoxicity_hERG_MACCSFP.csv) file.
# DataFrame base shape: (11504, 167)
# Shape after removing wrong values: (10635, 167)
# Shape after removing least used features: (10635, 118)
# Shape after removing outliers: (10396, 118)
#
# Preparing (ready_sets/cardiotoxicity_hERG_KlekFP.csv) file.
# DataFrame base shape: (11504, 4861)
# Shape after removing wrong values: (10635, 4861)
# Shape after removing least used features: (10635, 161)
# Shape after removing outliers: (10396, 161)
#
# Preparing (ready_sets/cardiotoxicity_hERG_ExtFP.csv) file.
# DataFrame base shape: (11504, 1025)
# Shape after removing wrong values: (10635, 1025)
# Shape after removing least used features: (10635, 1007)
# Shape after removing outliers: (10396, 1007)
#
#
# Using fetures that are present in at least 10.0% of substances.
#
# IC50 threshold for classification: 500
#
#
# 11.55% of substances classified as toxic, 88.45% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.931731    0.68018     {'C': 10, 'gamma': 0.01}
# SVC Poly                 0.924038    0.610837    {'C': 1, 'coef0': 1, 'degree': 2}
# SVC Linear               0.911538    0.611814    {'C': 0.1}
# Logistic                 0.920673    0.606205    {'C': 0.1}
# Random Forest            0.889904    0.087649    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.930288    0.650602    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.926442    0.622222    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.918269    0.617117    {'leaf_size': 20, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.931731    {'C': 10, 'gamma': 0.01}
#
#
# Best F1
# SVC RBF                  0.68018     {'C': 10, 'gamma': 0.01}
#     preccision           0.7365853658536585
#     recall               0.6317991631799164
#
# IC50 threshold for classification: 5000
#
#
# 37.78% of substances classified as toxic, 62.22% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.822115    0.751344    {'C': 10, 'gamma': 0.01}
# SVC Poly                 0.815385    0.747036    {'C': 1, 'coef0': 1, 'degree': 2}
# SVC Linear               0.788462    0.716129    {'C': 0.1}
# Logistic                 0.785577    0.708115    {'C': 0.1}
# Random Forest            0.696635    0.370887    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.815865    0.74347     {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.813462    0.737838    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.790385    0.719794    {'leaf_size': 20, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.822115    {'C': 10, 'gamma': 0.01}
#
#
# Best F1
# SVC RBF                  0.751344    {'C': 10, 'gamma': 0.01}
#     preccision           0.7840112201963534
#     recall               0.7212903225806452
#
# IC50 threshold for classification: 10000
#
#
# 50.17% of substances classified as toxic, 49.83% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:

# %% [markdown]
# Tutaj testuje metode SelectKBest do wyboru zmiennych.

# %%
# perc values adjusted to compare with previous method
for perc in [0.0119, 0.02, 0.059, 0.133, 0.21, 0.29]:
#     df_hashed = utils.get_hashed_fingerprints(min_perc_used=perc)
#     df_maccsfp = utils.get_MACCSFP_fingerprints(min_perc_used=perc)
#     df_klekota = utils.get_KlekotaRoth_fingerprints(min_perc_used=perc)
    df_mixed = utils.get_mixed_fingerprints(min_perc_used=perc)
    dfs = [
#         (df_hashed, "Hashed Extended Fingerprints"), 
#         (df_maccsfp, "MACCSFP Fingerprints"), 
#         (df_klekota, "Klekota&Roth Fingerprints"), 
        (df_mixed, "Mixed Fingerprints")
    ]

    print(f'\nUsing fetures that are present in at least {perc*100}% of substances.\n')
    for df, title in dfs:
        for IC50_threshold in [500, 5_000, 10_000, 50_000]:
            print(f'IC50 threshold for classification: {IC50_threshold} \n\n')
            df_class = utils.classify_on_IC50(df.copy(), IC50_threshold)
            X = df_class.drop('IC50', axis=1)
            y = df_class['IC50']
            select = int(X.shape[1] * perc)
            print(f'{round(y[y==1].shape[0]/y.shape[0] * 100, 2)}% of substances classified as toxic, {round(y[y==0].shape[0]/y.shape[0] * 100, 2)}% classified as non toxic.' , '\n')
            np.seterr(divide='ignore', invalid='ignore')
            X = SelectKBest(f_regression, k=select).fit_transform(X, y)
            print(title, '\n')
            perform_classification(X, y)
            print()
    print('\n\n')
# Out:
# Preparing files for mixed fingerprints.
#
# Preparing (ready_sets/cardiotoxicity_hERG_MACCSFP.csv) file.
# DataFrame base shape: (11504, 167)
# Shape after removing wrong values: (10635, 167)
# Shape after removing least used features: (10635, 138)
# Shape after removing outliers: (10396, 138)
#
# Preparing (ready_sets/cardiotoxicity_hERG_KlekFP.csv) file.
# DataFrame base shape: (11504, 4861)
# Shape after removing wrong values: (10635, 4861)
# Shape after removing least used features: (10635, 565)
# Shape after removing outliers: (10396, 565)
#
# Preparing (ready_sets/cardiotoxicity_hERG_ExtFP.csv) file.
# DataFrame base shape: (11504, 1025)
# Shape after removing wrong values: (10635, 1025)
# Shape after removing least used features: (10635, 1008)
# Shape after removing outliers: (10396, 1008)
#
#
# Using fetures that are present in at least 1.1900000000000002% of substances.
#
# IC50 threshold for classification: 500
#
#
# 11.55% of substances classified as toxic, 88.45% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.902885    0.412791    {'C': 100, 'gamma': 0.1}
# SVC Poly                 0.891346    0.215278    {'C': 1, 'coef0': 1, 'degree': 2}
# SVC Linear               0.883173    0.039526    {'C': 10}
# Logistic                 0.890865    0.180505    {'C': 100}
# Random Forest            0.888942    0.114943    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.896635    0.299674    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.9         0.384615    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.896635    0.410959    {'leaf_size': 50, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.902885    {'C': 100, 'gamma': 0.1}
#
#
# Best F1
# SVC RBF                  0.412791    {'C': 100, 'gamma': 0.1}
#     preccision           0.6761904761904762
#     recall               0.29707112970711297
#
# IC50 threshold for classification: 5000
#
#
# 37.78% of substances classified as toxic, 62.22% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.704327    0.547461    {'C': 100, 'gamma': 0.1}
# SVC Poly                 0.683654    0.448911    {'C': 1, 'coef0': 0.01, 'degree': 2}
# SVC Linear               0.679808    0.42487     {'C': 0.1}
# Logistic                 0.68125     0.429923    {'C': 100}
# Random Forest            0.689904    0.425646    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.704327    0.504432    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.702885    0.527523    {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 100}
# K Nearest Neighbors      0.678365    0.493565    {'leaf_size': 20, 'n_neighbors': 10}
#
# Best accuracy
# SVC RBF                  0.704327    {'C': 100, 'gamma': 0.1}
#
#
# Best F1
# SVC RBF                  0.547461    {'C': 100, 'gamma': 0.1}
#     preccision           0.636986301369863
#     recall               0.48
#
# IC50 threshold for classification: 10000
#
#
# 50.17% of substances classified as toxic, 49.83% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.667308    0.656746    {'C': 100, 'gamma': 'auto'}
# SVC Poly                 0.630288    0.617603    {'C': 1, 'coef0': 1, 'degree': 2}
# SVC Linear               0.627404    0.616526    {'C': 0.1}
# Logistic                 0.629327    0.619259    {'C': 0.1}
# Random Forest            0.6375      0.604822    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.654327    0.642111    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.674038    0.673095    {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 100}
# K Nearest Neighbors      0.660577    0.657614    {'leaf_size': 50, 'n_neighbors': 10}
#
# Best accuracy
# XGBoosting               0.674038    {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 100}
#
#
# Best F1
# XGBoosting               0.673095    {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 100}
#     preccision           0.6986986986986987
#     recall               0.6493023255813953
#
# IC50 threshold for classification: 50000
#
#
# 91.26% of substances classified as toxic, 8.74% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.920673    0.958302    {'C': 10, 'gamma': 'auto'}
# SVC Poly                 0.919712    0.957732    {'C': 1, 'coef0': 0.01, 'degree': 2}
# SVC Linear               0.918269    0.957114    {'C': 1}
# Logistic                 0.922115    0.958883    {'C': 100}
# Random Forest            0.920192    0.958081    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.923077    0.959432    {'learning_rate': 0.01, 'n_estimators': 500}
# XGBoosting               0.924519    0.960142    {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 50}
# K Nearest Neighbors      0.909615    0.951894    {'leaf_size': 50, 'n_neighbors': 10}
#
# Best accuracy
# XGBoosting               0.924519    {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 50}
#
#
# Best F1
# XGBoosting               0.960142    {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 50}
#     preccision           0.9292383292383293
#     recall               0.993172268907563
#
#
#
#
# Preparing files for mixed fingerprints.
#
# Preparing (ready_sets/cardiotoxicity_hERG_MACCSFP.csv) file.
# DataFrame base shape: (11504, 167)
# Shape after removing wrong values: (10635, 167)
# Shape after removing least used features: (10635, 135)
# Shape after removing outliers: (10396, 135)
#
# Preparing (ready_sets/cardiotoxicity_hERG_KlekFP.csv) file.
# DataFrame base shape: (11504, 4861)
# Shape after removing wrong values: (10635, 4861)
# Shape after removing least used features: (10635, 427)
# Shape after removing outliers: (10396, 427)
#
# Preparing (ready_sets/cardiotoxicity_hERG_ExtFP.csv) file.
# DataFrame base shape: (11504, 1025)
# Shape after removing wrong values: (10635, 1025)
# Shape after removing least used features: (10635, 1008)
# Shape after removing outliers: (10396, 1008)
#
#
# Using fetures that are present in at least 2.0% of substances.
#
# IC50 threshold for classification: 500
#
#
# 11.55% of substances classified as toxic, 88.45% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.913942    0.487106    {'C': 10, 'gamma': 0.1}
# SVC Poly                 0.896635    0.261168    {'C': 1, 'coef0': 1, 'degree': 2}
# SVC Linear               0.886538    0.024793    {'C': 0.1}
# Logistic                 0.890865    0.156134    {'C': 100}
# Random Forest            0.889423    0.115385    {'max_leaf_nodes': 16, 'n_estimators': 500}
# Gradient Boosting        0.905769    0.398773    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.913462    0.494382    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.912019    0.552567    {'leaf_size': 20, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.913942    {'C': 10, 'gamma': 0.1}
#
#
# Best F1
# K Nearest Neighbors      0.552567    {'leaf_size': 20, 'n_neighbors': 5}
#     preccision           0.6647058823529411
#     recall               0.47280334728033474
#
# IC50 threshold for classification: 5000
#
#
# 37.78% of substances classified as toxic, 62.22% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.759615    0.663073    {'C': 100, 'gamma': 0.1}
# SVC Poly                 0.708173    0.4971      {'C': 1, 'coef0': 1, 'degree': 2}
# SVC Linear               0.684135    0.481452    {'C': 1}
# Logistic                 0.689423    0.499225    {'C': 100}
# Random Forest            0.689904    0.426667    {'max_leaf_nodes': 16, 'n_estimators': 500}
# Gradient Boosting        0.720192    0.560423    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.741346    0.610145    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.742308    0.64219     {'leaf_size': 50, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.759615    {'C': 100, 'gamma': 0.1}
#
#
# Best F1
# SVC RBF                  0.663073    {'C': 100, 'gamma': 0.1}
#     preccision           0.693935119887165
#     recall               0.6348387096774194
#
# IC50 threshold for classification: 10000
#
#
# 50.17% of substances classified as toxic, 49.83% classified as non toxic.
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.712019    0.718118    {'C': 100, 'gamma': 0.1}
# SVC Poly                 0.670192    0.683579    {'C': 1, 'coef0': 0.01, 'degree': 2}
# SVC Linear               0.654808    0.653475    {'C': 0.1}
# Logistic                 0.651442    0.650265    {'C': 0.1}
# Random Forest            0.648077    0.616352    {'max_leaf_nodes': 16, 'n_estimators': 500}
# Gradient Boosting        0.675481    0.681754    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.694712    0.703963    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.700962    0.708529    {'leaf_size': 20, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.712019    {'C': 100, 'gamma': 0.1}
#
#
# Best F1
# SVC RBF                  0.718118    {'C': 100, 'gamma': 0.1}
#     preccision           0.7266666666666667
#     recall               0.7097674418604651
#
# IC50 threshold for classification: 50000
#
#
# 91.26% of substances classified as toxic, 8.74% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.925962    0.960973    {'C': 10, 'gamma': 0.1}
# SVC Poly                 0.920673    0.958281    {'C': 1, 'coef0': 0.01, 'degree': 2}
# SVC Linear               0.919712    0.957881    {'C': 0.1}
# Logistic                 0.917788    0.956785    {'C': 1}
# Random Forest            0.920192    0.958081    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.923558    0.959593    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.923558    0.959614    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 50}
# K Nearest Neighbors      0.921635    0.958556    {'leaf_size': 20, 'n_neighbors': 10}
#
# Best accuracy
# SVC RBF                  0.925962    {'C': 10, 'gamma': 0.1}
#
#
# Best F1
# SVC RBF                  0.960973    {'C': 10, 'gamma': 0.1}
#     preccision           0.9285014691478942
#     recall               0.9957983193277311
#
#
#
#
# Preparing files for mixed fingerprints.
#
# Preparing (ready_sets/cardiotoxicity_hERG_MACCSFP.csv) file.
# DataFrame base shape: (11504, 167)
# Shape after removing wrong values: (10635, 167)
# Shape after removing least used features: (10635, 126)
# Shape after removing outliers: (10396, 126)
#
# Preparing (ready_sets/cardiotoxicity_hERG_KlekFP.csv) file.
# DataFrame base shape: (11504, 4861)
# Shape after removing wrong values: (10635, 4861)
# Shape after removing least used features: (10635, 229)
# Shape after removing outliers: (10396, 229)
#
# Preparing (ready_sets/cardiotoxicity_hERG_ExtFP.csv) file.
# DataFrame base shape: (11504, 1025)
# Shape after removing wrong values: (10635, 1025)
# Shape after removing least used features: (10635, 1007)
# Shape after removing outliers: (10396, 1007)
#
#
# Using fetures that are present in at least 5.8999999999999995% of substances.
#
# IC50 threshold for classification: 500
#
#
# 11.55% of substances classified as toxic, 88.45% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.927885    0.668142    {'C': 10, 'gamma': 0.1}
# SVC Poly                 0.912981    0.449848    {'C': 1, 'coef0': 1, 'degree': 2}
# SVC Linear               0.887019    0.092664    {'C': 10}
# Logistic                 0.889423    0.172662    {'C': 0.1}
# Random Forest            0.888942    0.094118    {'max_leaf_nodes': 16, 'n_estimators': 500}
# Gradient Boosting        0.920673    0.545455    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.921154    0.556757    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.912019    0.561151    {'leaf_size': 50, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.927885    {'C': 10, 'gamma': 0.1}
#
#
# Best F1
# SVC RBF                  0.668142    {'C': 10, 'gamma': 0.1}
#     preccision           0.7089201877934272
#     recall               0.6317991631799164
#
# IC50 threshold for classification: 5000
#
#
# 37.78% of substances classified as toxic, 62.22% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.808654    0.743226    {'C': 10, 'gamma': 0.1}
# SVC Poly                 0.778365    0.672353    {'C': 1, 'coef0': 1, 'degree': 2}
# SVC Linear               0.7125      0.564774    {'C': 0.1}
# Logistic                 0.714904    0.55447     {'C': 0.01}
# Random Forest            0.698077    0.44523     {'max_leaf_nodes': 16, 'n_estimators': 500}
# Gradient Boosting        0.772115    0.671745    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.794231    0.70725     {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.790385    0.716883    {'leaf_size': 50, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.808654    {'C': 10, 'gamma': 0.1}
#
#
# Best F1
# SVC RBF                  0.743226    {'C': 10, 'gamma': 0.1}
#     preccision           0.743225806451613
#     recall               0.743225806451613
#
# IC50 threshold for classification: 10000
#
#
# 50.17% of substances classified as toxic, 49.83% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.767788    0.770109    {'C': 10, 'gamma': 0.1}
# SVC Poly                 0.744712    0.749646    {'C': 1, 'coef0': 1, 'degree': 2}
# SVC Linear               0.689904    0.694168    {'C': 0.1}
# Logistic                 0.690385    0.695364    {'C': 100}
# Random Forest            0.665865    0.644137    {'max_leaf_nodes': 16, 'n_estimators': 500}
# Gradient Boosting        0.741827    0.745377    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.740385    0.74212     {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.747115    0.751887    {'leaf_size': 50, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.767788    {'C': 10, 'gamma': 0.1}
#
#
# Best F1
# SVC RBF                  0.770109    {'C': 10, 'gamma': 0.1}
#     preccision           0.7884990253411306
#     recall               0.7525581395348837
#
# IC50 threshold for classification: 50000
#
#
# 91.26% of substances classified as toxic, 8.74% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.933173    0.964477    {'C': 100, 'gamma': 0.01}
# SVC Poly                 0.928365    0.962135    {'C': 1, 'coef0': 0.01, 'degree': 2}
# SVC Linear               0.920192    0.958144    {'C': 1}
# Logistic                 0.920192    0.957847    {'C': 10}
# Random Forest            0.921635    0.958849    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.935577    0.965641    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.929808    0.962506    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.926442    0.960759    {'leaf_size': 50, 'n_neighbors': 10}
#
# Best accuracy
# Gradient Boosting        0.935577    {'learning_rate': 0.1, 'n_estimators': 500}
#
#
# Best F1
# Gradient Boosting        0.965641    {'learning_rate': 0.1, 'n_estimators': 500}
#     preccision           0.9433867735470942
#     recall               0.9889705882352942
#
#
#
#
# Preparing files for mixed fingerprints.
#
# Preparing (ready_sets/cardiotoxicity_hERG_MACCSFP.csv) file.
# DataFrame base shape: (11504, 167)
# Shape after removing wrong values: (10635, 167)
# Shape after removing least used features: (10635, 100)
# Shape after removing outliers: (10396, 100)
#
# Preparing (ready_sets/cardiotoxicity_hERG_KlekFP.csv) file.
# DataFrame base shape: (11504, 4861)
# Shape after removing wrong values: (10635, 4861)
# Shape after removing least used features: (10635, 130)
# Shape after removing outliers: (10396, 130)
#
# Preparing (ready_sets/cardiotoxicity_hERG_ExtFP.csv) file.
# DataFrame base shape: (11504, 1025)
# Shape after removing wrong values: (10635, 1025)
# Shape after removing least used features: (10635, 992)
# Shape after removing outliers: (10396, 992)
#
#
# Using fetures that are present in at least 13.3% of substances.
#
# IC50 threshold for classification: 500
#
#
# 11.55% of substances classified as toxic, 88.45% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.929327    0.663616    {'C': 100, 'gamma': 0.1}
# SVC Poly                 0.913942    0.506887    {'C': 1, 'coef0': 1, 'degree': 2}
# SVC Linear               0.895192    0.296774    {'C': 10}
# Logistic                 0.894231    0.337349    {'C': 1}
# Random Forest            0.888942    0.079681    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.924519    0.594315    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.922596    0.581818    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.912019    0.577367    {'leaf_size': 50, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.929327    {'C': 100, 'gamma': 0.1}
#
#
# Best F1
# SVC RBF                  0.663616    {'C': 100, 'gamma': 0.1}
#     preccision           0.7323232323232324
#     recall               0.606694560669456
#
# IC50 threshold for classification: 5000
#
#
# 37.78% of substances classified as toxic, 62.22% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.823558    0.758075    {'C': 100, 'gamma': 0.1}
# SVC Poly                 0.799519    0.712215    {'C': 1, 'coef0': 0.01, 'degree': 2}
# SVC Linear               0.729327    0.59757     {'C': 0.1}
# Logistic                 0.732212    0.603559    {'C': 0.1}
# Random Forest            0.706731    0.447464    {'max_leaf_nodes': 16, 'n_estimators': 500}
# Gradient Boosting        0.790865    0.706676    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.789423    0.702849    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.784615    0.709468    {'leaf_size': 20, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.823558    {'C': 100, 'gamma': 0.1}
#
#
# Best F1
# SVC RBF                  0.758075    {'C': 100, 'gamma': 0.1}
#     preccision           0.7749326145552561
#     recall               0.7419354838709677
#
# IC50 threshold for classification: 10000
#
#
# 50.17% of substances classified as toxic, 49.83% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.785096    0.782904    {'C': 10, 'gamma': 0.1}
# SVC Poly                 0.766346    0.767908    {'C': 1, 'coef0': 0.01, 'degree': 2}
# SVC Linear               0.696154    0.703565    {'C': 0.1}
# Logistic                 0.693269    0.701311    {'C': 0.1}
# Random Forest            0.664904    0.641276    {'max_leaf_nodes': 16, 'n_estimators': 500}
# Gradient Boosting        0.769231    0.770774    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.746154    0.747368    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.763942    0.770453    {'leaf_size': 50, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.785096    {'C': 10, 'gamma': 0.1}
#
#
# Best F1
# SVC RBF                  0.782904    {'C': 10, 'gamma': 0.1}
#     preccision           0.8191056910569106
#     recall               0.7497674418604651
#
# IC50 threshold for classification: 50000
#
#
# 91.26% of substances classified as toxic, 8.74% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.933654    0.964597    {'C': 10, 'gamma': 0.01}
# SVC Poly                 0.929808    0.962812    {'C': 1, 'coef0': 0.01, 'degree': 2}
# SVC Linear               0.922115    0.958925    {'C': 1}
# Logistic                 0.925962    0.960734    {'C': 1}
# Random Forest            0.921635    0.958849    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.935096    0.965305    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.93125     0.96338     {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 100}
# K Nearest Neighbors      0.928846    0.961954    {'leaf_size': 20, 'n_neighbors': 5}
#
# Best accuracy
# Gradient Boosting        0.935096    {'learning_rate': 0.1, 'n_estimators': 500}
#
#
# Best F1
# Gradient Boosting        0.965305    {'learning_rate': 0.1, 'n_estimators': 500}
#     preccision           0.9451434323100151
#     recall               0.9863445378151261
#
#
#
#
# Preparing files for mixed fingerprints.
#
# Preparing (ready_sets/cardiotoxicity_hERG_MACCSFP.csv) file.
# DataFrame base shape: (11504, 167)
# Shape after removing wrong values: (10635, 167)
# Shape after removing least used features: (10635, 89)
# Shape after removing outliers: (10396, 89)
#
# Preparing (ready_sets/cardiotoxicity_hERG_KlekFP.csv) file.
# DataFrame base shape: (11504, 4861)
# Shape after removing wrong values: (10635, 4861)
# Shape after removing least used features: (10635, 93)
# Shape after removing outliers: (10396, 93)
#
# Preparing (ready_sets/cardiotoxicity_hERG_ExtFP.csv) file.
# DataFrame base shape: (11504, 1025)
# Shape after removing wrong values: (10635, 1025)
# Shape after removing least used features: (10635, 882)
# Shape after removing outliers: (10396, 882)
#
#
# Using fetures that are present in at least 21.0% of substances.
#
# IC50 threshold for classification: 500
#
#
# 11.55% of substances classified as toxic, 88.45% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.930769    0.661972    {'C': 10, 'gamma': 0.01}
# SVC Poly                 0.923077    0.574468    {'C': 1, 'coef0': 1, 'degree': 2}
# SVC Linear               0.897596    0.328076    {'C': 10}
# Logistic                 0.902885    0.412791    {'C': 10}
# Random Forest            0.889423    0.094488    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.925       0.61194     {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.924038    0.620192    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.918269    0.620536    {'leaf_size': 50, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.930769    {'C': 10, 'gamma': 0.01}
#
#
# Best F1
# SVC RBF                  0.661972    {'C': 10, 'gamma': 0.01}
#     preccision           0.7540106951871658
#     recall               0.5899581589958159
#
# IC50 threshold for classification: 5000
#
#
# 37.78% of substances classified as toxic, 62.22% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.820192    0.757458    {'C': 10, 'gamma': 0.01}
# SVC Poly                 0.813462    0.735695    {'C': 1, 'coef0': 1, 'degree': 2}
# SVC Linear               0.730288    0.616541    {'C': 1}
# Logistic                 0.730769    0.593023    {'C': 0.01}
# Random Forest            0.709135    0.443422    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.808654    0.730717    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.797596    0.714576    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.794231    0.723871    {'leaf_size': 50, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.820192    {'C': 10, 'gamma': 0.01}
#
#
# Best F1
# SVC RBF                  0.757458    {'C': 10, 'gamma': 0.01}
#     preccision           0.7614080834419817
#     recall               0.7535483870967742
#
# IC50 threshold for classification: 10000
#
#
# 50.17% of substances classified as toxic, 49.83% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.790385    0.792972    {'C': 10, 'gamma': 0.01}
# SVC Poly                 0.768269    0.769157    {'C': 1, 'coef0': 1, 'degree': 2}
# SVC Linear               0.702404    0.711422    {'C': 0.1}
# Logistic                 0.698077    0.704887    {'C': 0.1}
# Random Forest            0.671635    0.648482    {'max_leaf_nodes': 16, 'n_estimators': 500}
# Gradient Boosting        0.776442    0.777831    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.769231    0.769674    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.763462    0.769231    {'leaf_size': 50, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.790385    {'C': 10, 'gamma': 0.01}
#
#
# Best F1
# SVC RBF                  0.792972    {'C': 10, 'gamma': 0.01}
#     preccision           0.8098933074684772
#     recall               0.7767441860465116
#
# IC50 threshold for classification: 50000
#
#
# 91.26% of substances classified as toxic, 8.74% classified as non toxic.
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.934135    0.964682    {'C': 10, 'gamma': 0.01}
# SVC Poly                 0.93125     0.963455    {'C': 1, 'coef0': 0.01, 'degree': 2}
# SVC Linear               0.923558    0.959511    {'C': 1}
# Logistic                 0.925962    0.960734    {'C': 0.1}
# Random Forest            0.921154    0.958649    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.933173    0.964166    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.928846    0.961856    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.927404    0.961133    {'leaf_size': 50, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.934135    {'C': 10, 'gamma': 0.01}
#
#
# Best F1
# SVC RBF                  0.964682    {'C': 10, 'gamma': 0.01}
#     preccision           0.9473417721518987
#     recall               0.9826680672268907
#
#
#
#
# Preparing files for mixed fingerprints.
#
# Preparing (ready_sets/cardiotoxicity_hERG_MACCSFP.csv) file.
# DataFrame base shape: (11504, 167)
# Shape after removing wrong values: (10635, 167)
# Shape after removing least used features: (10635, 80)
# Shape after removing outliers: (10396, 80)
#
# Preparing (ready_sets/cardiotoxicity_hERG_KlekFP.csv) file.
# DataFrame base shape: (11504, 4861)
# Shape after removing wrong values: (10635, 4861)
# Shape after removing least used features: (10635, 70)
# Shape after removing outliers: (10396, 70)
#
# Preparing (ready_sets/cardiotoxicity_hERG_ExtFP.csv) file.
# DataFrame base shape: (11504, 1025)
# Shape after removing wrong values: (10635, 1025)
# Shape after removing least used features: (10635, 684)
# Shape after removing outliers: (10396, 684)
#
#
# Using fetures that are present in at least 28.999999999999996% of substances.
#
# IC50 threshold for classification: 500
#
#
# 11.55% of substances classified as toxic, 88.45% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.930288    0.662005    {'C': 10, 'gamma': 0.01}
# SVC Poly                 0.924519    0.581333    {'C': 1, 'coef0': 1, 'degree': 2}
# SVC Linear               0.90625     0.40367     {'C': 1}
# Logistic                 0.903846    0.441341    {'C': 10}
# Random Forest            0.889423    0.094488    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.927404    0.617722    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.917788    0.583942    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.91875     0.61678     {'leaf_size': 20, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.930288    {'C': 10, 'gamma': 0.01}
#
#
# Best F1
# SVC RBF                  0.662005    {'C': 10, 'gamma': 0.01}
#     preccision           0.7473684210526316
#     recall               0.5941422594142259
#
# IC50 threshold for classification: 5000
#
#
# 37.78% of substances classified as toxic, 62.22% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.829327    0.767822    {'C': 10, 'gamma': 0.01}
# SVC Poly                 0.808173    0.731675    {'C': 1, 'coef0': 1, 'degree': 2}
# SVC Linear               0.746635    0.63224     {'C': 1}
# Logistic                 0.74375     0.627012    {'C': 10}
# Random Forest            0.70625     0.433735    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.795673    0.713419    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.8         0.716621    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.791346    0.71671     {'leaf_size': 20, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.829327    {'C': 10, 'gamma': 0.01}
#
#
# Best F1
# SVC RBF                  0.767822    {'C': 10, 'gamma': 0.01}
#     preccision           0.7785145888594165
#     recall               0.7574193548387097
#
# IC50 threshold for classification: 10000
#
#
# 50.17% of substances classified as toxic, 49.83% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.771635    0.762143    {'C': 100, 'gamma': 0.1}
# SVC Poly                 0.777885    0.779159    {'C': 1, 'coef0': 0.01, 'degree': 2}
# SVC Linear               0.700962    0.705213    {'C': 0.1}
# Logistic                 0.700481    0.705437    {'C': 0.1}
# Random Forest            0.667308    0.646939    {'max_leaf_nodes': 16, 'n_estimators': 500}
# Gradient Boosting        0.781731    0.783603    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.764904    0.76681     {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.760577    0.764873    {'leaf_size': 50, 'n_neighbors': 5}
#
# Best accuracy
# Gradient Boosting        0.781731    {'learning_rate': 0.1, 'n_estimators': 500}
#
#
# Best F1
# Gradient Boosting        0.783603    {'learning_rate': 0.1, 'n_estimators': 500}
#     preccision           0.8035190615835777
#     recall               0.7646511627906977
#
# IC50 threshold for classification: 50000
#
#
# 91.26% of substances classified as toxic, 8.74% classified as non toxic.
#
# Mixed Fingerprints
#
# Classification model:    accuracy:   F1:
# SVC RBF                  0.9375      0.966356    {'C': 10, 'gamma': 0.01}
# SVC Poly                 0.930288    0.962982    {'C': 1, 'coef0': 0.01, 'degree': 2}
# SVC Linear               0.921635    0.958619    {'C': 0.1}
# Logistic                 0.925       0.960285    {'C': 0.1}
# Random Forest            0.921154    0.958628    {'max_leaf_nodes': 16, 'n_estimators': 100}
# Gradient Boosting        0.926923    0.960946    {'learning_rate': 0.1, 'n_estimators': 500}
# XGBoosting               0.935096    0.965464    {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# K Nearest Neighbors      0.929808    0.962429    {'leaf_size': 50, 'n_neighbors': 5}
#
# Best accuracy
# SVC RBF                  0.9375      {'C': 10, 'gamma': 0.01}
#
#
# Best F1
# SVC RBF                  0.966356    {'C': 10, 'gamma': 0.01}
#     preccision           0.9525510204081633
#     recall               0.9805672268907563

# %% [markdown]
# Na koniec przetestowałem jeszcze prostą sieć neuronową

# %%
def perform_NN_classification(X, y):
    history = History()
    model = Sequential()

    size = X.shape[1]
    model.add(Dense(size//2, activation="relu",input_shape=(size,)))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(size//4, activation="relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(size//8, activation="relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(size//16, activation="relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(size//32, activation="relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(1,activation="sigmoid"))
    model.summary()


    early_stopping = EarlyStopping(patience=30, monitor="val_loss")
    model.compile(loss='binary_crossentropy', optimizer="Adam", metrics=["accuracy"])

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=seed)

    model.fit(X_train, y_train, validation_data= (X_test, y_test), batch_size=256, epochs=200, validation_split=0.2, callbacks=[early_stopping, history], verbose=0)
    prediction = (model.predict(X_test) > 0.5).astype("int32")
    accuracy = accuracy_score(y_test, prediction)
    f1 = f1_score(y_test, prediction)
    print(f'\nFinal accuracy:   {accuracy}')
    print(f'\nFinal f1 score:   {f1}')
    print()

# %%
for perc in [0.9, 0.8, 0.5, 0.3, 0.1, 0.01]:
#     df_hashed = utils.get_hashed_fingerprints(min_perc_used=perc)
#     df_maccsfp = utils.get_MACCSFP_fingerprints(min_perc_used=perc)
#     df_klekota = utils.get_KlekotaRoth_fingerprints(min_perc_used=perc)
    df_mixed = utils.get_mixed_fingerprints(min_perc_used=perc)
    dfs = [
#         (df_hashed, "Hashed Extended Fingerprints"), 
#         (df_maccsfp, "MACCSFP Fingerprints"), 
#         (df_klekota, "Klekota&Roth Fingerprints"), 
        (df_mixed, "Mixed Fingerprints")
    ]

    print(f'\nUsing fetures that are present in at least {perc*100}% of substances.\n')
    for df, title in dfs:
        for IC50_threshold in [500, 5_000, 10_000, 50_000]:
            print(f'IC50 threshold for classification: {IC50_threshold} \n\n')
            df_class = utils.classify_on_IC50(df.copy(), IC50_threshold)
            X = df_class.drop('IC50', axis=1)
            y = df_class['IC50']
            print(f'{round(y[y==1].shape[0]/y.shape[0] * 100, 2)}% of substances classified as toxic, {round(y[y==0].shape[0]/y.shape[0] * 100, 2)}% classified as non toxic.' , '\n')
            print(title, '\n')
            perform_NN_classification(X, y)
            print()
    print('\n\n')
# Out:
# Preparing files for mixed fingerprints.
#
# Preparing (ready_sets/cardiotoxicity_hERG_MACCSFP.csv) file.
# DataFrame base shape: (11504, 167)
# Shape after removing wrong values: (10635, 167)
# Shape after removing least used features: (10635, 15)
# Shape after removing outliers: (10396, 15)
#
# Preparing (ready_sets/cardiotoxicity_hERG_KlekFP.csv) file.
# DataFrame base shape: (11504, 4861)
# Shape after removing wrong values: (10635, 4861)
# Shape after removing least used features: (10635, 9)
# Shape after removing outliers: (10396, 9)
#
# Preparing (ready_sets/cardiotoxicity_hERG_ExtFP.csv) file.
# DataFrame base shape: (11504, 1025)
# Shape after removing wrong values: (10635, 1025)
# Shape after removing least used features: (10635, 51)
# Shape after removing outliers: (10396, 51)
#
#
# Using fetures that are present in at least 90.0% of substances.
#
# IC50 threshold for classification: 500
#
#
# 11.55% of substances classified as toxic, 88.45% classified as non toxic.
#
# Mixed Fingerprints
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 36)                2628
#
#  batch_normalization (BatchN  (None, 36)               144
#  ormalization)
#
#  dropout (Dropout)           (None, 36)                0
#
#  dense_1 (Dense)             (None, 18)                666
#
#  batch_normalization_1 (Batc  (None, 18)               72
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 18)                0
#
#  dense_2 (Dense)             (None, 9)                 171
#
#  batch_normalization_2 (Batc  (None, 9)                36
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 9)                 0
#
#  dense_3 (Dense)             (None, 4)                 40
#
#  batch_normalization_3 (Batc  (None, 4)                16
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 4)                 0
#
#  dense_4 (Dense)             (None, 2)                 10
#
#  batch_normalization_4 (Batc  (None, 2)                8
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 2)                 0
#
#  dense_5 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 3,794
# Trainable params: 3,656
# Non-trainable params: 138
# _________________________________________________________________
#
# Final accuracy:   0.8850961538461538
#
# Final f1 score:   0.0
#
#
# IC50 threshold for classification: 5000
#
#
# 37.78% of substances classified as toxic, 62.22% classified as non toxic.
#
# Mixed Fingerprints
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 36)                2628
#
#  batch_normalization_5 (Batc  (None, 36)               144
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 36)                0
#
#  dense_7 (Dense)             (None, 18)                666
#
#  batch_normalization_6 (Batc  (None, 18)               72
#  hNormalization)
#
#  dropout_6 (Dropout)         (None, 18)                0
#
#  dense_8 (Dense)             (None, 9)                 171
#
#  batch_normalization_7 (Batc  (None, 9)                36
#  hNormalization)
#
#  dropout_7 (Dropout)         (None, 9)                 0
#
#  dense_9 (Dense)             (None, 4)                 40
#
#  batch_normalization_8 (Batc  (None, 4)                16
#  hNormalization)
#
#  dropout_8 (Dropout)         (None, 4)                 0
#
#  dense_10 (Dense)            (None, 2)                 10
#
#  batch_normalization_9 (Batc  (None, 2)                8
#  hNormalization)
#
#  dropout_9 (Dropout)         (None, 2)                 0
#
#  dense_11 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 3,794
# Trainable params: 3,656
# Non-trainable params: 138
# _________________________________________________________________
#
# Final accuracy:   0.6274038461538461
#
# Final f1 score:   0.0
#
#
# IC50 threshold for classification: 10000
#
#
# 50.17% of substances classified as toxic, 49.83% classified as non toxic.
#
# Mixed Fingerprints
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 36)                2628
#
#  batch_normalization_10 (Bat  (None, 36)               144
#  chNormalization)
#
#  dropout_10 (Dropout)        (None, 36)                0
#
#  dense_13 (Dense)            (None, 18)                666
#
#  batch_normalization_11 (Bat  (None, 18)               72
#  chNormalization)
#
#  dropout_11 (Dropout)        (None, 18)                0
#
#  dense_14 (Dense)            (None, 9)                 171
#
#  batch_normalization_12 (Bat  (None, 9)                36
#  chNormalization)
#
#  dropout_12 (Dropout)        (None, 9)                 0
#
#  dense_15 (Dense)            (None, 4)                 40
#
#  batch_normalization_13 (Bat  (None, 4)                16
#  chNormalization)
#
#  dropout_13 (Dropout)        (None, 4)                 0
#
#  dense_16 (Dense)            (None, 2)                 10
#
#  batch_normalization_14 (Bat  (None, 2)                8
#  chNormalization)
#
#  dropout_14 (Dropout)        (None, 2)                 0
#
#  dense_17 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 3,794
# Trainable params: 3,656
# Non-trainable params: 138
# _________________________________________________________________
# Final accuracy:   0.4831730769230769
#
# Final f1 score:   0.0
#
#
# IC50 threshold for classification: 50000
#
#
# 91.26% of substances classified as toxic, 8.74% classified as non toxic.
#
# Mixed Fingerprints
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 36)                2628
#
#  batch_normalization_15 (Bat  (None, 36)               144
#  chNormalization)
#
#  dropout_15 (Dropout)        (None, 36)                0
#
#  dense_19 (Dense)            (None, 18)                666
#
#  batch_normalization_16 (Bat  (None, 18)               72
#  chNormalization)
#
#  dropout_16 (Dropout)        (None, 18)                0
#
#  dense_20 (Dense)            (None, 9)                 171
#
#  batch_normalization_17 (Bat  (None, 9)                36
#  chNormalization)
#
#  dropout_17 (Dropout)        (None, 9)                 0
#
#  dense_21 (Dense)            (None, 4)                 40
#
#  batch_normalization_18 (Bat  (None, 4)                16
#  chNormalization)
#
#  dropout_18 (Dropout)        (None, 4)                 0
#
#  dense_22 (Dense)            (None, 2)                 10
#
#  batch_normalization_19 (Bat  (None, 2)                8
#  chNormalization)
#
#  dropout_19 (Dropout)        (None, 2)                 0
#
#  dense_23 (Dense)            (None, 1)                 3
#
# =================================================================
# Total params: 3,794
# Trainable params: 3,656
# Non-trainable params: 138
# _________________________________________________________________
#
# Final accuracy:   0.9153846153846154
#
# Final f1 score:   0.9558232931726908
#
#
#
#
#
# Preparing files for mixed fingerprints.
#
# Preparing (ready_sets/cardiotoxicity_hERG_MACCSFP.csv) file.
# DataFrame base shape: (11504, 167)
# Shape after removing wrong values: (10635, 167)
# Shape after removing least used features: (10635, 25)
# Shape after removing outliers: (10396, 25)
#
# Preparing (ready_sets/cardiotoxicity_hERG_KlekFP.csv) file.
# DataFrame base shape: (11504, 4861)
# Shape after removing wrong values: (10635, 4861)
# Shape after removing least used features: (10635, 15)
# Shape after removing outliers: (10396, 15)
#
# Preparing (ready_sets/cardiotoxicity_hERG_ExtFP.csv) file.
# DataFrame base shape: (11504, 1025)
# Shape after removing wrong values: (10635, 1025)
# Shape after removing least used features: (10635, 84)
# Shape after removing outliers: (10396, 84)
#
#
# Using fetures that are present in at least 80.0% of substances.
#
# IC50 threshold for classification: 500
#
#
# 11.55% of substances classified as toxic, 88.45% classified as non toxic.
#
# Mixed Fingerprints
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 60)                7320
#
#  batch_normalization_20 (Bat  (None, 60)               240
#  chNormalization)
#
#  dropout_20 (Dropout)        (None, 60)                0
#
#  dense_25 (Dense)            (None, 30)                1830
#
#  batch_normalization_21 (Bat  (None, 30)               120
#  chNormalization)
#
#  dropout_21 (Dropout)        (None, 30)                0
#
#  dense_26 (Dense)            (None, 15)                465
#
#  batch_normalization_22 (Bat  (None, 15)               60
#  chNormalization)
#
#  dropout_22 (Dropout)        (None, 15)                0
#
#  dense_27 (Dense)            (None, 7)                 112
#
#  batch_normalization_23 (Bat  (None, 7)                28
#  chNormalization)
#
#  dropout_23 (Dropout)        (None, 7)                 0
#
#  dense_28 (Dense)            (None, 3)                 24
#
#  batch_normalization_24 (Bat  (None, 3)                12
#  chNormalization)
#
#  dropout_24 (Dropout)        (None, 3)                 0
#
#  dense_29 (Dense)            (None, 1)                 4
#
# =================================================================
# Total params: 10,215
# Trainable params: 9,985
# Non-trainable params: 230
# _________________________________________________________________
#
# Final accuracy:   0.8850961538461538
#
# Final f1 score:   0.0
#
#
# IC50 threshold for classification: 5000
#
#
# 37.78% of substances classified as toxic, 62.22% classified as non toxic.
#
# Mixed Fingerprints
#
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_30 (Dense)            (None, 60)                7320
#
#  batch_normalization_25 (Bat  (None, 60)               240
#  chNormalization)
#
#  dropout_25 (Dropout)        (None, 60)                0
#
#  dense_31 (Dense)            (None, 30)                1830
#
#  batch_normalization_26 (Bat  (None, 30)               120
#  chNormalization)
#
#  dropout_26 (Dropout)        (None, 30)                0
#
#  dense_32 (Dense)            (None, 15)                465
#
#  batch_normalization_27 (Bat  (None, 15)               60
#  chNormalization)
#
#  dropout_27 (Dropout)        (None, 15)                0
#
#  dense_33 (Dense)            (None, 7)                 112
#
#  batch_normalization_28 (Bat  (None, 7)                28
#  chNormalization)
#
#  dropout_28 (Dropout)        (None, 7)                 0
#
#  dense_34 (Dense)            (None, 3)                 24
#
#  batch_normalization_29 (Bat  (None, 3)                12
#  chNormalization)
#
#  dropout_29 (Dropout)        (None, 3)                 0
#
#  dense_35 (Dense)            (None, 1)                 4
#
# =================================================================
# Total params: 10,215
# Trainable params: 9,985
# Non-trainable params: 230
# _________________________________________________________________
# Final accuracy:   0.6538461538461539
#
# Final f1 score:   0.16473317865429238
#
#
# IC50 threshold for classification: 10000
#
#
# 50.17% of substances classified as toxic, 49.83% classified as non toxic.
#
# Mixed Fingerprints
#
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_36 (Dense)            (None, 60)                7320
#
#  batch_normalization_30 (Bat  (None, 60)               240
#  chNormalization)
#
#  dropout_30 (Dropout)        (None, 60)                0
#
#  dense_37 (Dense)            (None, 30)                1830
#
#  batch_normalization_31 (Bat  (None, 30)               120
#  chNormalization)
#
#  dropout_31 (Dropout)        (None, 30)                0
#
#  dense_38 (Dense)            (None, 15)                465
#
#  batch_normalization_32 (Bat  (None, 15)               60
#  chNormalization)
#
#  dropout_32 (Dropout)        (None, 15)                0
#
#  dense_39 (Dense)            (None, 7)                 112
#
#  batch_normalization_33 (Bat  (None, 7)                28
#  chNormalization)
#
#  dropout_33 (Dropout)        (None, 7)                 0
#
#  dense_40 (Dense)            (None, 3)                 24
#
#  batch_normalization_34 (Bat  (None, 3)                12
#  chNormalization)
#
#  dropout_34 (Dropout)        (None, 3)                 0
#
#  dense_41 (Dense)            (None, 1)                 4
#
# =================================================================
# Total params: 10,215
# Trainable params: 9,985
# Non-trainable params: 230
# _________________________________________________________________
#
# Final accuracy:   0.5740384615384615
#
# Final f1 score:   0.698844323589395
#
#
# IC50 threshold for classification: 50000
#
#
# 91.26% of substances classified as toxic, 8.74% classified as non toxic.
#
# Mixed Fingerprints
#
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_42 (Dense)            (None, 60)                7320
#
#  batch_normalization_35 (Bat  (None, 60)               240
#  chNormalization)
#
#  dropout_35 (Dropout)        (None, 60)                0
#
#  dense_43 (Dense)            (None, 30)                1830
#
#  batch_normalization_36 (Bat  (None, 30)               120
#  chNormalization)
#
#  dropout_36 (Dropout)        (None, 30)                0
#
#  dense_44 (Dense)            (None, 15)                465
#
#  batch_normalization_37 (Bat  (None, 15)               60
#  chNormalization)
#
#  dropout_37 (Dropout)        (None, 15)                0
#
#  dense_45 (Dense)            (None, 7)                 112
#
#  batch_normalization_38 (Bat  (None, 7)                28
#  chNormalization)
#
#  dropout_38 (Dropout)        (None, 7)                 0
#
#  dense_46 (Dense)            (None, 3)                 24
#
#  batch_normalization_39 (Bat  (None, 3)                12
#  chNormalization)
#
#  dropout_39 (Dropout)        (None, 3)                 0
#
#  dense_47 (Dense)            (None, 1)                 4
#
# =================================================================
# Total params: 10,215
# Trainable params: 9,985
# Non-trainable params: 230
# _________________________________________________________________
#
# Final accuracy:   0.9153846153846154
#
# Final f1 score:   0.9558232931726908
#
#
#
#
#
# Preparing files for mixed fingerprints.
#
# Preparing (ready_sets/cardiotoxicity_hERG_MACCSFP.csv) file.
# DataFrame base shape: (11504, 167)
# Shape after removing wrong values: (10635, 167)
# Shape after removing least used features: (10635, 59)
# Shape after removing outliers: (10396, 59)
#
# Preparing (ready_sets/cardiotoxicity_hERG_KlekFP.csv) file.
# DataFrame base shape: (11504, 4861)
# Shape after removing wrong values: (10635, 4861)
# Shape after removing least used features: (10635, 36)
# Shape after removing outliers: (10396, 36)
#
# Preparing (ready_sets/cardiotoxicity_hERG_ExtFP.csv) file.
# DataFrame base shape: (11504, 1025)
# Shape after removing wrong values: (10635, 1025)
# Shape after removing least used features: (10635, 264)
# Shape after removing outliers: (10396, 264)
#
#
# Using fetures that are present in at least 50.0% of substances.
#
# IC50 threshold for classification: 500
#
#
# 11.55% of substances classified as toxic, 88.45% classified as non toxic.
#
# Mixed Fingerprints
#
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_48 (Dense)            (None, 178)               63546
#
#  batch_normalization_40 (Bat  (None, 178)              712
#  chNormalization)
#
#  dropout_40 (Dropout)        (None, 178)               0
#
#  dense_49 (Dense)            (None, 89)                15931
#
#  batch_normalization_41 (Bat  (None, 89)               356
#  chNormalization)
#
#  dropout_41 (Dropout)        (None, 89)                0
#
#  dense_50 (Dense)            (None, 44)                3960
#
#  batch_normalization_42 (Bat  (None, 44)               176
#  chNormalization)
#
#  dropout_42 (Dropout)        (None, 44)                0
#
#  dense_51 (Dense)            (None, 22)                990
#
#  batch_normalization_43 (Bat  (None, 22)               88
#  chNormalization)
#
#  dropout_43 (Dropout)        (None, 22)                0
#
#  dense_52 (Dense)            (None, 11)                253
#
#  batch_normalization_44 (Bat  (None, 11)               44
#  chNormalization)
#
#  dropout_44 (Dropout)        (None, 11)                0
#
#  dense_53 (Dense)            (None, 1)                 12
#
# =================================================================
# Total params: 86,068
# Trainable params: 85,380
# Non-trainable params: 688
# _________________________________________________________________
# Final accuracy:   0.9115384615384615
#
# Final f1 score:   0.5422885572139303
#
#
# IC50 threshold for classification: 5000
#
#
# 37.78% of substances classified as toxic, 62.22% classified as non toxic.
#
# Mixed Fingerprints
#
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_54 (Dense)            (None, 178)               63546
#
#  batch_normalization_45 (Bat  (None, 178)              712
#  chNormalization)
#
#  dropout_45 (Dropout)        (None, 178)               0
#
#  dense_55 (Dense)            (None, 89)                15931
#
#  batch_normalization_46 (Bat  (None, 89)               356
#  chNormalization)
#
#  dropout_46 (Dropout)        (None, 89)                0
#
#  dense_56 (Dense)            (None, 44)                3960
#
#  batch_normalization_47 (Bat  (None, 44)               176
#  chNormalization)
#
#  dropout_47 (Dropout)        (None, 44)                0
#
#  dense_57 (Dense)            (None, 22)                990
#
#  batch_normalization_48 (Bat  (None, 22)               88
#  chNormalization)
#
#  dropout_48 (Dropout)        (None, 22)                0
#
#  dense_58 (Dense)            (None, 11)                253
#
#  batch_normalization_49 (Bat  (None, 11)               44
#  chNormalization)
#
#  dropout_49 (Dropout)        (None, 11)                0
#
#  dense_59 (Dense)            (None, 1)                 12
#
# =================================================================
# Total params: 86,068
# Trainable params: 85,380
# Non-trainable params: 688
# _________________________________________________________________
#
# Final accuracy:   0.7408653846153846
#
# Final f1 score:   0.7056253413435281
#
#
# IC50 threshold for classification: 10000
#
#
# 50.17% of substances classified as toxic, 49.83% classified as non toxic.
#
# Mixed Fingerprints
#
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_60 (Dense)            (None, 178)               63546
#
#  batch_normalization_50 (Bat  (None, 178)              712
#  chNormalization)
#
#  dropout_50 (Dropout)        (None, 178)               0
#
#  dense_61 (Dense)            (None, 89)                15931
#
#  batch_normalization_51 (Bat  (None, 89)               356
#  chNormalization)
#
#  dropout_51 (Dropout)        (None, 89)                0
#
#  dense_62 (Dense)            (None, 44)                3960
#
#  batch_normalization_52 (Bat  (None, 44)               176
#  chNormalization)
#
#  dropout_52 (Dropout)        (None, 44)                0
#
#  dense_63 (Dense)            (None, 22)                990
#
#  batch_normalization_53 (Bat  (None, 22)               88
#  chNormalization)
#
#  dropout_53 (Dropout)        (None, 22)                0
#
#  dense_64 (Dense)            (None, 11)                253
#
#  batch_normalization_54 (Bat  (None, 11)               44
#  chNormalization)
#
#  dropout_54 (Dropout)        (None, 11)                0
#
#  dense_65 (Dense)            (None, 1)                 12
#
# =================================================================
# Total params: 86,068
# Trainable params: 85,380
# Non-trainable params: 688
# _________________________________________________________________
#
# Final accuracy:   0.73125
#
# Final f1 score:   0.7228557263262272
#
#
# IC50 threshold for classification: 50000
#
#
# 91.26% of substances classified as toxic, 8.74% classified as non toxic.
#
# Mixed Fingerprints
#
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_66 (Dense)            (None, 178)               63546
#
#  batch_normalization_55 (Bat  (None, 178)              712
#  chNormalization)
#
#  dropout_55 (Dropout)        (None, 178)               0
#
#  dense_67 (Dense)            (None, 89)                15931
#
#  batch_normalization_56 (Bat  (None, 89)               356
#  chNormalization)
#
#  dropout_56 (Dropout)        (None, 89)                0
#
#  dense_68 (Dense)            (None, 44)                3960
#
#  batch_normalization_57 (Bat  (None, 44)               176
#  chNormalization)
#
#  dropout_57 (Dropout)        (None, 44)                0
#
#  dense_69 (Dense)            (None, 22)                990
#
#  batch_normalization_58 (Bat  (None, 22)               88
#  chNormalization)
#
#  dropout_58 (Dropout)        (None, 22)                0
#
#  dense_70 (Dense)            (None, 11)                253
#
#  batch_normalization_59 (Bat  (None, 11)               44
#  chNormalization)
#
#  dropout_59 (Dropout)        (None, 11)                0
#
#  dense_71 (Dense)            (None, 1)                 12
#
# =================================================================
# Total params: 86,068
# Trainable params: 85,380
# Non-trainable params: 688
# _________________________________________________________________
# Final accuracy:   0.9264423076923077
#
# Final f1 score:   0.9609992352791231
#
#
#
#
#
# Preparing files for mixed fingerprints.
#
# Preparing (ready_sets/cardiotoxicity_hERG_MACCSFP.csv) file.
# DataFrame base shape: (11504, 167)
# Shape after removing wrong values: (10635, 167)
# Shape after removing least used features: (10635, 80)
# Shape after removing outliers: (10396, 80)
#
# Preparing (ready_sets/cardiotoxicity_hERG_KlekFP.csv) file.
# DataFrame base shape: (11504, 4861)
# Shape after removing wrong values: (10635, 4861)
# Shape after removing least used features: (10635, 70)
# Shape after removing outliers: (10396, 70)
#
# Preparing (ready_sets/cardiotoxicity_hERG_ExtFP.csv) file.
# DataFrame base shape: (11504, 1025)
# Shape after removing wrong values: (10635, 1025)
# Shape after removing least used features: (10635, 655)
# Shape after removing outliers: (10396, 655)
#
#
# Using fetures that are present in at least 30.0% of substances.
#
# IC50 threshold for classification: 500
#
#
# 11.55% of substances classified as toxic, 88.45% classified as non toxic.
#
# Mixed Fingerprints
#
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_72 (Dense)            (None, 401)               322003
#
#  batch_normalization_60 (Bat  (None, 401)              1604
#  chNormalization)
#
#  dropout_60 (Dropout)        (None, 401)               0
#
#  dense_73 (Dense)            (None, 200)               80400
#
#  batch_normalization_61 (Bat  (None, 200)              800
#  chNormalization)
#
#  dropout_61 (Dropout)        (None, 200)               0
#
#  dense_74 (Dense)            (None, 100)               20100
#
#  batch_normalization_62 (Bat  (None, 100)              400
#  chNormalization)
#
#  dropout_62 (Dropout)        (None, 100)               0
#
#  dense_75 (Dense)            (None, 50)                5050
#
#  batch_normalization_63 (Bat  (None, 50)               200
#  chNormalization)
#
#  dropout_63 (Dropout)        (None, 50)                0
#
#  dense_76 (Dense)            (None, 25)                1275
#
#  batch_normalization_64 (Bat  (None, 25)               100
#  chNormalization)
#
#  dropout_64 (Dropout)        (None, 25)                0
#
#  dense_77 (Dense)            (None, 1)                 26
#
# =================================================================
# Total params: 431,958
# Trainable params: 430,406
# Non-trainable params: 1,552
# _________________________________________________________________
#
# Final accuracy:   0.9149038461538461
#
# Final f1 score:   0.5354330708661418
#
#
# IC50 threshold for classification: 5000
#
#
# 37.78% of substances classified as toxic, 62.22% classified as non toxic.
#
# Mixed Fingerprints
#
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_78 (Dense)            (None, 401)               322003
#
#  batch_normalization_65 (Bat  (None, 401)              1604
#  chNormalization)
#
#  dropout_65 (Dropout)        (None, 401)               0
#
#  dense_79 (Dense)            (None, 200)               80400
#
#  batch_normalization_66 (Bat  (None, 200)              800
#  chNormalization)
#
#  dropout_66 (Dropout)        (None, 200)               0
#
#  dense_80 (Dense)            (None, 100)               20100
#
#  batch_normalization_67 (Bat  (None, 100)              400
#  chNormalization)
#
#  dropout_67 (Dropout)        (None, 100)               0
#
#  dense_81 (Dense)            (None, 50)                5050
#
#  batch_normalization_68 (Bat  (None, 50)               200
#  chNormalization)
#
#  dropout_68 (Dropout)        (None, 50)                0
#
#  dense_82 (Dense)            (None, 25)                1275
#
#  batch_normalization_69 (Bat  (None, 25)               100
#  chNormalization)
#
#  dropout_69 (Dropout)        (None, 25)                0
#
#  dense_83 (Dense)            (None, 1)                 26
#
# =================================================================
# Total params: 431,958
# Trainable params: 430,406
# Non-trainable params: 1,552
# _________________________________________________________________
#
# Final accuracy:   0.80625
#
# Final f1 score:   0.7171929824561405
#
#
# IC50 threshold for classification: 10000
#
#
# 50.17% of substances classified as toxic, 49.83% classified as non toxic.
#
# Mixed Fingerprints
#
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_84 (Dense)            (None, 401)               322003
#
#  batch_normalization_70 (Bat  (None, 401)              1604
#  chNormalization)
#
#  dropout_70 (Dropout)        (None, 401)               0
#
#  dense_85 (Dense)            (None, 200)               80400
#
#  batch_normalization_71 (Bat  (None, 200)              800
#  chNormalization)
#
#  dropout_71 (Dropout)        (None, 200)               0
#
#  dense_86 (Dense)            (None, 100)               20100
#
#  batch_normalization_72 (Bat  (None, 100)              400
#  chNormalization)
# ...
# =================================================================
#  dense_114 (Dense)           (None, 641)               823044
#
#  batch_normalization_95 (Bat  (None, 641)              2564
#  chNormalization)
#
#  dropout_95 (Dropout)        (None, 641)               0
#
#  dense_115 (Dense)           (None, 320)               205440
#
#  batch_normalization_96 (Bat  (None, 320)              1280
#  chNormalization)
#
#  dropout_96 (Dropout)        (None, 320)               0
#
#  dense_116 (Dense)           (None, 160)               51360
#
#  batch_normalization_97 (Bat  (None, 160)              640
#  chNormalization)
#
#  dropout_97 (Dropout)        (None, 160)               0
#
#  dense_117 (Dense)           (None, 80)                12880
#
#  batch_normalization_98 (Bat  (None, 80)               320
#  chNormalization)
#
#  dropout_98 (Dropout)        (None, 80)                0
#
#  dense_118 (Dense)           (None, 40)                3240
#
#  batch_normalization_99 (Bat  (None, 40)               160
#  chNormalization)
#
#  dropout_99 (Dropout)        (None, 40)                0
#
#  dense_119 (Dense)           (None, 1)                 41
#
# =================================================================
# Total params: 1,100,969
# Trainable params: 1,098,487
# Non-trainable params: 2,482
# _________________________________________________________________
#
# Final accuracy:   0.9322115384615385
#
# Final f1 score:   0.964131264309336
#
#
#
#
#
# Preparing files for mixed fingerprints.
#
# Preparing (ready_sets/cardiotoxicity_hERG_MACCSFP.csv) file.
# DataFrame base shape: (11504, 167)
# Shape after removing wrong values: (10635, 167)
# Shape after removing least used features: (10635, 138)
# Shape after removing outliers: (10396, 138)
#
# Preparing (ready_sets/cardiotoxicity_hERG_KlekFP.csv) file.
# DataFrame base shape: (11504, 4861)
# Shape after removing wrong values: (10635, 4861)
# Shape after removing least used features: (10635, 619)
# Shape after removing outliers: (10396, 619)
#
# Preparing (ready_sets/cardiotoxicity_hERG_ExtFP.csv) file.
# DataFrame base shape: (11504, 1025)
# Shape after removing wrong values: (10635, 1025)
# Shape after removing least used features: (10635, 1008)
# Shape after removing outliers: (10396, 1008)
#
#
# Using fetures that are present in at least 1.0% of substances.
#
# IC50 threshold for classification: 500
#
#
# 11.55% of substances classified as toxic, 88.45% classified as non toxic.
#
# Mixed Fingerprints
#
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_120 (Dense)           (None, 881)               1553203
#
#  batch_normalization_100 (Ba  (None, 881)              3524
#  tchNormalization)
#
#  dropout_100 (Dropout)       (None, 881)               0
#
#  dense_121 (Dense)           (None, 440)               388080
#
#  batch_normalization_101 (Ba  (None, 440)              1760
#  tchNormalization)
#
#  dropout_101 (Dropout)       (None, 440)               0
#
#  dense_122 (Dense)           (None, 220)               97020
#
#  batch_normalization_102 (Ba  (None, 220)              880
#  tchNormalization)
#
#  dropout_102 (Dropout)       (None, 220)               0
#
#  dense_123 (Dense)           (None, 110)               24310
#
#  batch_normalization_103 (Ba  (None, 110)              440
#  tchNormalization)
#
#  dropout_103 (Dropout)       (None, 110)               0
#
#  dense_124 (Dense)           (None, 55)                6105
#
#  batch_normalization_104 (Ba  (None, 55)               220
#  tchNormalization)
#
#  dropout_104 (Dropout)       (None, 55)                0
#
#  dense_125 (Dense)           (None, 1)                 56
#
# =================================================================
# Total params: 2,075,598
# Trainable params: 2,072,186
# Non-trainable params: 3,412
# _________________________________________________________________
# Final accuracy:   0.9115384615384615
#
# Final f1 score:   0.47727272727272724
#
#
# IC50 threshold for classification: 5000
#
#
# 37.78% of substances classified as toxic, 62.22% classified as non toxic.
#
# Mixed Fingerprints
#
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_126 (Dense)           (None, 881)               1553203
#
#  batch_normalization_105 (Ba  (None, 881)              3524
#  tchNormalization)
#
#  dropout_105 (Dropout)       (None, 881)               0
#
#  dense_127 (Dense)           (None, 440)               388080
#
#  batch_normalization_106 (Ba  (None, 440)              1760
#  tchNormalization)
#
#  dropout_106 (Dropout)       (None, 440)               0
#
#  dense_128 (Dense)           (None, 220)               97020
#
#  batch_normalization_107 (Ba  (None, 220)              880
#  tchNormalization)
#
#  dropout_107 (Dropout)       (None, 220)               0
#
#  dense_129 (Dense)           (None, 110)               24310
#
#  batch_normalization_108 (Ba  (None, 110)              440
#  tchNormalization)
#
#  dropout_108 (Dropout)       (None, 110)               0
#
#  dense_130 (Dense)           (None, 55)                6105
#
#  batch_normalization_109 (Ba  (None, 55)               220
#  tchNormalization)
#
#  dropout_109 (Dropout)       (None, 55)                0
#
#  dense_131 (Dense)           (None, 1)                 56
#
# =================================================================
# Total params: 2,075,598
# Trainable params: 2,072,186
# Non-trainable params: 3,412
# _________________________________________________________________
#
# Final accuracy:   0.8125
#
# Final f1 score:   0.732876712328767
#
#
# IC50 threshold for classification: 10000
#
#
# 50.17% of substances classified as toxic, 49.83% classified as non toxic.
#
# Mixed Fingerprints
#
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_132 (Dense)           (None, 881)               1553203
#
#  batch_normalization_110 (Ba  (None, 881)              3524
#  tchNormalization)
#
#  dropout_110 (Dropout)       (None, 881)               0
#
#  dense_133 (Dense)           (None, 440)               388080
#
#  batch_normalization_111 (Ba  (None, 440)              1760
#  tchNormalization)
#
#  dropout_111 (Dropout)       (None, 440)               0
#
#  dense_134 (Dense)           (None, 220)               97020
#
#  batch_normalization_112 (Ba  (None, 220)              880
#  tchNormalization)
#
#  dropout_112 (Dropout)       (None, 220)               0
#
#  dense_135 (Dense)           (None, 110)               24310
#
#  batch_normalization_113 (Ba  (None, 110)              440
#  tchNormalization)
#
#  dropout_113 (Dropout)       (None, 110)               0
#
#  dense_136 (Dense)           (None, 55)                6105
#
#  batch_normalization_114 (Ba  (None, 55)               220
#  tchNormalization)
#
#  dropout_114 (Dropout)       (None, 55)                0
#
#  dense_137 (Dense)           (None, 1)                 56
#
# =================================================================
# Total params: 2,075,598
# Trainable params: 2,072,186
# Non-trainable params: 3,412
# _________________________________________________________________
#
# Final accuracy:   0.7798076923076923
#
# Final f1 score:   0.787569573283859
#
#
# IC50 threshold for classification: 50000
#
#
# 91.26% of substances classified as toxic, 8.74% classified as non toxic.
#
# Mixed Fingerprints
#
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_138 (Dense)           (None, 881)               1553203
#
#  batch_normalization_115 (Ba  (None, 881)              3524
#  tchNormalization)
#
#  dropout_115 (Dropout)       (None, 881)               0
#
#  dense_139 (Dense)           (None, 440)               388080
#
#  batch_normalization_116 (Ba  (None, 440)              1760
#  tchNormalization)
#
#  dropout_116 (Dropout)       (None, 440)               0
#
#  dense_140 (Dense)           (None, 220)               97020
#
#  batch_normalization_117 (Ba  (None, 220)              880
#  tchNormalization)
#
#  dropout_117 (Dropout)       (None, 220)               0
#
#  dense_141 (Dense)           (None, 110)               24310
#
#  batch_normalization_118 (Ba  (None, 110)              440
#  tchNormalization)
#
#  dropout_118 (Dropout)       (None, 110)               0
#
#  dense_142 (Dense)           (None, 55)                6105
#
#  batch_normalization_119 (Ba  (None, 55)               220
#  tchNormalization)
#
#  dropout_119 (Dropout)       (None, 55)                0
#
#  dense_143 (Dense)           (None, 1)                 56
#
# =================================================================
# Total params: 2,075,598
# Trainable params: 2,072,186
# Non-trainable params: 3,412
# _________________________________________________________________
# Final accuracy:   0.9350961538461539
#
# Final f1 score:   0.9655348480980342
